# %% [markdown]
# # Basic Stock Charts
# Just some simple examples of stock related charts to test out the different libraries

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as datetime
import time
import os
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
# %run finance.ipynb #import of the functions defined in the finance.ipynb notebook

# %%
tickers = ['AAPL','TSLA','COST','DIS','JD']
start_date = '2019-01-01'
end_date = '2023-01-01'

# %%
ptf = getPtf(tickers,start_date,end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
ptf.head()
# Out:
#                    JD                                                         \
#                  Open       High    Low  Close  Adj Close    Volume Adj Open
# Date
# 2018-12-31  22.040001  22.480000  20.77  20.93  20.414927  19422400  21.4976
# 2019-01-02  20.309999  21.480000  20.18  21.27  20.746559  15840000  19.8102
# 2019-01-03  20.889999  21.139999  20.25  20.35  19.849199  18608000  20.3759
# 2019-01-04  20.980000  22.680000  20.75  22.27  21.721949  25156900  20.4637
# 2019-01-07  22.430000  22.850000  22.26  22.76  22.199890  18889800  21.8780
#
#                                            ...       AAPL                    \
#            Adj High  Adj Low Daily Return  ...     Volume Adj Open Adj High
# Date                                       ...
# 2018-12-31  21.9268  20.2589          NaN  ...  140014000  38.3158  38.5164
# 2019-01-02  20.9514  19.6834     0.016245  ...  148158800  37.4360  38.3931
# 2019-01-03  20.6198  19.7517    -0.043253  ...  365248800  34.7991  35.2197
# 2019-01-04  22.1219  20.2394     0.094349  ...  234428400  34.9321  35.9037
# 2019-01-07  22.2877  21.7122     0.022003  ...  219111200  35.9399  35.9713
#
#                                                                           \
#             Adj Low Daily Return Log Return Cumulative Return MA 10 Days
# Date
# 2018-12-31  37.8203          NaN        NaN               NaN        NaN
# 2019-01-02  37.2765     0.001141   0.001140          1.001141        NaN
# 2019-01-03  34.3206    -0.099607  -0.104924          0.901420        NaN
# 2019-01-04  34.7556     0.042689   0.041803          0.939901        NaN
# 2019-01-07  35.2632    -0.002226  -0.002229          0.937809        NaN
#
#
#            MA 20 Days MA 50 Days
# Date
# 2018-12-31        NaN        NaN
# 2019-01-02        NaN        NaN
# 2019-01-03        NaN        NaN
# 2019-01-04        NaN        NaN
# 2019-01-07        NaN        NaN
#
# [5 rows x 75 columns]

# %%
#some charts using seaborn
fig, (ax1, ax2 ) = plt.subplots(1, 2,figsize=(25,6))
sns.lineplot(data = getSpecificColumns(ptf, 'Cumulative Return',ptf.columns.levels[0]), ax = ax1)
sns.violinplot(data = getSpecificColumns(ptf, 'Daily Return', ptf.columns.levels[0]), ax = ax2)
# Out:
# <AxesSubplot:>

# %%
ptf.JD
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-12-31  22.040001  22.480000  20.770000  20.930000  20.414927  19422400
# 2019-01-02  20.309999  21.480000  20.180000  21.270000  20.746559  15840000
# 2019-01-03  20.889999  21.139999  20.250000  20.350000  19.849199  18608000
# 2019-01-04  20.980000  22.680000  20.750000  22.270000  21.721949  25156900
# 2019-01-07  22.430000  22.850000  22.260000  22.760000  22.199890  18889800
# ...               ...        ...        ...        ...        ...       ...
# 2022-09-02  62.009998  62.130001  60.889999  61.290001  61.290001   4541100
# 2022-09-06  59.610001  60.119999  59.000000  59.349998  59.349998   4376800
# 2022-09-07  58.950001  60.049999  58.020000  59.880001  59.880001   4845900
# 2022-09-08  59.299999  60.360001  59.220001  59.910000  59.910000   2941700
# 2022-09-09  61.470001  61.880001  60.200001  60.410000  60.410000   5020900
#
#             Adj Open  Adj High  Adj Low  Daily Return  Log Return  \
# Date
# 2018-12-31   21.4976   21.9268  20.2589           NaN         NaN
# 2019-01-02   19.8102   20.9514  19.6834      0.016245    0.016114
# 2019-01-03   20.3759   20.6198  19.7517     -0.043253   -0.044217
# 2019-01-04   20.4637   22.1219  20.2394      0.094349    0.090160
# 2019-01-07   21.8780   22.2877  21.7122      0.022003    0.021764
# ...              ...       ...      ...           ...         ...
# 2022-09-02   62.0100   62.1300  60.8900     -0.028839   -0.029263
# 2022-09-06   59.6100   60.1200  59.0000     -0.031653   -0.032165
# 2022-09-07   58.9500   60.0500  58.0200      0.008930    0.008890
# 2022-09-08   59.3000   60.3600  59.2200      0.000501    0.000501
# 2022-09-09   61.4700   61.8800  60.2000      0.008346    0.008311
#
#             Cumulative Return
# Date
# 2018-12-31                NaN
# 2019-01-02           1.016245
# 2019-01-03           0.972289
# 2019-01-04           1.064023
# 2019-01-07           1.087434
# ...                       ...
# 2022-09-02           3.002215
# 2022-09-06           2.907186
# 2022-09-07           2.933148
# 2022-09-08           2.934617
# 2022-09-09           2.959109
#
# [931 rows x 12 columns]

# %%
#create chart with double Y axis, for price and volume
fig, ax1 = plt.subplots(figsize = (20,10))
sns.lineplot(data = ptf.JD.reset_index(), x = ptf.JD.reset_index().Date, y = ptf.JD.reset_index()['Adj Close'], ax = ax1, color = 'red')
ax2 = ax1.twinx()
sns.barplot(data = ptf.JD.reset_index(), x = ptf.JD.reset_index().Date, y = ptf.JD.reset_index()['Volume'] , ax = ax2, palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Volume'>

# %%
n = randomWeights(len(ptf.columns.levels[0]))
ptfPerformance(n, ptf)
# Out:
# (0.3659102591346536, 0.2921082421428356)

# %%
fig, ax1 = plt.subplots(figsize = (20,10))
sns.lineplot(data = ptf.JD[['Adj Close','MA 10 Days','MA 20 Days','MA 50 Days']])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (25,8))
sns.lineplot(data = ptf.JD[['Daily Return']], markers = True, dashes = True, ax = ax1)
sns.histplot(data = ptf.JD['Daily Return'], bins = 100, color = 'blue', kde = True, ax = ax2)
# Out:
# <AxesSubplot:xlabel='Daily Return', ylabel='Count'>

# %%
sns.jointplot(x = ptf.JD['Daily Return'], y = ptf.TSLA['Daily Return'], data = ptf, kind='scatter')

# %%
sns.pairplot(ptf.xs('Daily Return', level = 1, axis = 1))

# %%
#sns.heatmap correlation plot
